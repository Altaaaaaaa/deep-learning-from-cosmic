# %% [markdown]
# <font color=green>#하이퍼볼릭 함수 : 다른종류의 활성화함수</font>

# %%
import numpy as np

# 하이퍼볼릭 탄젠트
def tanh(x):
    p_exp_x = np.exp(x)
    m_exp_x = np.exp(-x)
    
    y = (p_exp_x - m_exp_x)/(p_exp_x + m_exp_x)
    
    return y

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-5.0, 5.0, 0.1)
y = tanh(x)

# 캔버스 설정
fig = plt.figure(figsize=(10,7)) # 캔버스 생성
fig.set_facecolor('white')      # 캔버스 색상 설정

plt.plot(x, y)
plt.title("Hyperbolic Tangent", fontsize=30)
plt.xlabel('x', fontsize=20)
plt.ylabel('y', fontsize=20, rotation=0)

plt.yticks([-1.0, 0.0, 1.0]) # 특정 축에서 특정 값만 나오게
plt.axvline(0.0, color='k')
ax = plt.gca()
ax.yaxis.grid(True) # y축에 있는 모든 숫자에 회색 점근선을 그음

plt.show()

# %% [markdown]
# 왜쓰는가?
# -하이퍼볼릭 탄젠트는 중앙값이 0이기 때문에, 경사하강법 사용 시 시그모이드 함수에서 발생하는 편향 이동이 발생하지 않는다. 즉, 기울기가 양수 음수 모두 나올 수 있기 때문에 시그모이드 함수보다 학습 효율성이 뛰어나다.

# %% [markdown]
# #미분해보기
# https://gooopy.tistory.com/54#:~:text=%ED%95%98%EC%9D%B4%ED%8D%BC%EB%B3%BC%EB%A6%AD%20%ED%83%84%EC%A0%A0%ED%8A%B8%EB%8A%94%20%EC%A4%91%EC%95%99%EA%B0%92,%EB%B3%B4%EB%8B%A4%20%ED%95%99%EC%8A%B5%20%ED%9A%A8%EC%9C%A8%EC%84%B1%EC%9D%B4%20%EB%9B%B0%EC%96%B4%EB%82%98%EB%8B%A4.

# %%
import matplotlib.pylab as plt

x = plt.arange(-10.0, 10.0, 0.1)
y2 = diff_tanh(x)

fig = plt.figure(figsize=(10,5))

plt.plot(x, y2, c = 'green', label = "diff_tanh")

plt.title("tanh", fontsize=30)
plt.xlabel('x', fontsize=20)
plt.ylabel('y', fontsize=20, rotation=0)

plt.ylim(-0.5, 2)
plt.xlim(-7, 7)

plt.legend(loc = "upper right")

plt.axvline(0.0, color='k')
ax = plt.gca()
ax.yaxis.grid(True)
ax.xaxis.grid(True)

plt.show()
